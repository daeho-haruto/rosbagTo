# %%
import pandas as pd

data = pd.read_csv("../data/rosbag2_2023_02_01-17_05_01/rosToCsv2023_02_02-04_20_28.csv")
data
# Out:
#                                         topic            timestamp  \
# 0                                  /tf_static  1675238701853306053
# 1                                         /tf  1675238701853313998
# 2                          /robot_description  1675238701853318263
# 3          /navigation/global_costmap/costmap  1675238701853475446
# 4      /navigation/global_costmap/costmap_raw  1675238701853632530
# ...                                       ...                  ...
# 49844                        /navigation/bond  1675238770444099836
# 49845                                     /tf  1675238770444607315
# 49846                           /joint_states  1675238770444615638
# 49847                                   /odom  1675238770444621636
# 49848                        /navigation/bond  1675238770449352474
#
#                      message_type  \
# 0          tf2_msgs/msg/TFMessage
# 1          tf2_msgs/msg/TFMessage
# 2             std_msgs/msg/String
# ...
